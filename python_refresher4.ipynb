# %% [markdown]
# Python refresher 4
#
# work with tuples

# %%
import numpy as np
from math import *
import pandas as pd
import matplotlib.pyplot as plt
import scipy

# %%
# a tuple
coords = (4, 5)
print(coords[0])
# cannot change tuples
# coords[0] = 2 # returns error

coords2 = [(1, 2), (3, 4), (5, 6)] # this is a list, that can be changed
coords2[0] = 8 # changing even works like this, replace (1, 2) by single number 8
print(coords2)
# Out:
# 4
# [8, (3, 4), (5, 6)]

# %% [markdown]
# now more

# %%
print("Hello, World!")
# Out:
# Hello, World!
