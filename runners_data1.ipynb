# %% [markdown]
# Attempt 1 at swiss runners data

# %% [markdown]
# Tasks
# ------
# 1. Get data from swiss 10k championships 2023 and 2024
# 2. structure data in google drive spreadsheet
# 3. read data in here with python
# 4. make prediction about 2025 swiss 10k championship winners
