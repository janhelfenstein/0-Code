# %% [markdown]
# 9. Palindrome Number
# Given an integer x, return true if x is a palindrome, and false otherwise.
# Example 1:
#
# Input: x = 121
# Output: true
# Explanation: 121 reads as 121 from left to right and from right to left.
# Example 2:
#
# Input: x = -121
# Output: false
# Explanation: From left to right, it reads -121. From right to left, it becomes 121-. Therefore it is not a palindrome.
# Example 3:
#
# Input: x = 10
# Output: false
# Explanation: Reads 01 from right to left. Therefore it is not a palindrome.

# %%
def isPalindrome(x):
    """
    :type x: int
    :rtype: bool
    """
    answer = True
    s = str(x)
    length = len(s)
    for i in range(length):
        if s[i] != s[length -1 - i]:
            return False
    return answer

# test cases
x = 121
answer = isPalindrome(x)
print(answer)

x = -121
answer = isPalindrome(x)
print(answer)

x = 10
answer = isPalindrome(x)
print(answer)
# Out:
# True
# False
# False

# %% [markdown]
# do it with reversing the number and comparing the two numbers

# %%
def isPalindrome(x):
    """
    :type x: int
    :rtype: bool
    """
    if x < 0:
       return False

    #reverse number
    reverse = 0
    digit = 0
    temp = x
    while temp != 0:
        digit = temp % 10
        reverse = reverse * 10
        reverse += digit
        temp -= digit
        temp = temp / 10

    if reverse == x:
        return True
    return False

# test cases
x = 121
answer = isPalindrome(x)
print(answer)

x = -121
answer = isPalindrome(x)
print(answer)

x = 10
answer = isPalindrome(x)
print(answer)
# Out:
# True
# False
# False

# %%
def isPalindrome(x):
    """
    :type x: int
    :rtype: bool
    """
    if x < 0:
       return False

    #reverse number
    reverse = 0
    digit = 0
    temp = x
    while temp != 0:
        digit = temp % 10
        reverse = reverse * 10 + digit
        temp -= digit
        temp /= 10

    return reverse == x

# test cases
x = 121
answer = isPalindrome(x)
print(answer)

x = -121
answer = isPalindrome(x)
print(answer)

x = 10
answer = isPalindrome(x)
print(answer)
# Out:
# True
# False
# False
