# %% [markdown]
# Python Refresher 3
#
# continue with python course from Youtube:
# https://www.youtube.com/watch?v=rfscVS0vtbw&t=377s

# %%
import numpy as np
import matplotlib as plt
import math
import scipy
import pandas as pd
from math import *

# %%
# more playing with numbers

num = -5
print(abs(num), np.sign(num))
print(pow(num, 3)) # 5^3
print(np.exp(5))
print(max(4, 5, 6, 2, 1))
array1 = np.array([1, 3, 5, 7, 9, 2, 4, 6, 8])
print(min(array1), max(array1))
print(np.mean(array1), np.median(array1))
print(floor(3.71), ceil(3.71))
print(sqrt(36), sqrt(20))
# Out:
# 5 -1
# -125.0
# 148.4131591025766
# 6
# 1 9
# 5.0 5.0
# 3 4
# 6.0 4.47213595499958

# %%
# user input
print("You can interact with the user with the input() command.")
name = input("Enter your name: ")
age = input("Enter your age: ")
print("Hello,", name, ", you are", age, "years old.")

num1 = input("Enter a number: ")
num2 = input("Enter another number: ")
result = num1 + num2
print(result) # this will print a string num1num2, will not mathematically add the numbers!
# result = int(num1) + int(num2) # will return a numerical result, but only if they are integers.
result2 = float(num1) + float(num2) # fix with floating numbers
# Out:
# You can interact with the user with the input() command.
# Hello, a , you are 65 years old.
# 6234.3
